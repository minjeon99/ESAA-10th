# %% [markdown]
# <a href="https://colab.research.google.com/github/minjeon99/ESAA_YB/blob/Week4/w4_mon_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **12. 시계열 데이터**

# %% [markdown]
# ## **12-1. datetime 오브젝트**
# - `datetime` 라이브러리: 날짜, 시간 처리 파이썬 라이브러리
#   - `date` 오브젝트: 날짜 처리
#   - `time` 오브젝트: 시간 처리
#   - `datetime` 오브젝트: 날짜, 시간 처리

# %%
# import datetime 라이브러리
from datetime import datetime

# %% [markdown]
# - `now()`, `today()` 메서드: 현재 시간 출력

# %%
now1 = datetime.now()
print(now1)
# Out:
# 2024-03-28 11:32:14.653476

# %%
now2 = datetime.today()
print(now2)
# Out:
# 2024-03-28 11:32:16.509803

# %% [markdown]
# **시간 직접 입력하여 인자로 전달**

# %%
t1 = datetime.now()
t2 = datetime(1970,1,1)
t3 = datetime(1970,12,12,13,24,34)

print(t1)
print(t2)
print(t3)
# Out:
# 2024-03-28 11:33:23.292580
# 1970-01-01 00:00:00
# 1970-12-12 13:24:34

# %% [markdown]
# **시간 계산**

# %%
diff1 = t1 - t2
print(diff1)
print(type(diff1))

diff2 = t2 - t1
print(diff2)
print(type(diff2))
# Out:
# 19810 days, 11:33:23.292580
# <class 'datetime.timedelta'>
# -19811 days, 12:26:36.707420
# <class 'datetime.timedelta'>

# %% [markdown]
# - datetime끼리 시간 계산하면 `days`로 나옴

# %% [markdown]
# ### **datetime 오브젝트로 변환하기 - to_datetime 메서드**
# - `to_datetime()`: 문자열로 저장된 시계열 데이터 -> datetime 오브젝트로 변환

# %%
import pandas as pd
import os

ebola = pd.read_csv('/content/country_timeseries.csv')

# %%
print(ebola.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %% [markdown]
# - 문자열로 저장된 Date 열이 있음

# %%
ebola['date_dt'] = pd.to_datetime(ebola['Date'])
print(ebola.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %% [markdown]
# **format 인자 사용법**
# - **시간 형식 지정자(%d, %m, %y)**와 기호(/,-) 조합하여 `format` 인자에 전달

# %%
test_df1 = pd.DataFrame({'order_day':['01/01/15', '02/01/15', '03/01/15']})

test_df1['date_dt1'] = pd.to_datetime(test_df1['order_day'], format='%d/%m/%y')
test_df1['date_dt2'] = pd.to_datetime(test_df1['order_day'], format='%m/%d/%y')
test_df1['date_dt3'] = pd.to_datetime(test_df1['order_day'], format='%y/%m/%d')

print(test_df1)
# Out:
#   order_day   date_dt1   date_dt2   date_dt3
# 0  01/01/15 2015-01-01 2015-01-01 2001-01-15
# 1  02/01/15 2015-01-02 2015-02-01 2002-01-15
# 2  03/01/15 2015-01-03 2015-03-01 2003-01-15

# %%
test_df2 = pd.DataFrame({'order_day':['01-01-15','02-01-15','03-01-15']})
test_df2['date_df'] = pd.to_datetime(test_df2['order_day'], format='%d-%m-%y')
print(test_df2)
# Out:
#   order_day    date_df
# 0  01-01-15 2015-01-01
# 1  02-01-15 2015-01-02
# 2  03-01-15 2015-01-03

# %% [markdown]
# ### **시간 형식 지정자**
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **시계열 데이터 구분해서 추출**
# - `strftime()` 메서드, 시간 형식자 이용

# %%
now = datetime.now()
print(now)
# Out:
# 2024-03-28 11:54:14.926556

# %%
nowDate = now.strftime('%Y-%m-%d')
print(nowDate)
# Out:
# 2024-03-28

# %%
nowTime = now.strftime('%H:%M:%S')
print(nowTime)
# Out:
# 11:54:14

# %%
nowDatetime = now.strftime('%Y-%m-%d %H:%M:%S')
print(nowDatetime)
# Out:
# 2024-03-28 11:54:14

# %% [markdown]
# ### **datetime 오브젝트로 변환하기 - read_csv 메서드**

# %% [markdown]
# **datetime 오브젝트로 변환하려는 열 지정하여 데이터 불러오기**
# - `parse_dates` 인자: datetime 오브젝트로 변환하고자 하는 열의 이름 전달

# %%
ebola1 = pd.read_csv('/content/country_timeseries.csv', parse_dates=['Date'])
print(ebola1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %% [markdown]
# ### **datetime 오브젝트에서 날짜 정보 추출하기**

# %%
date_series = pd.Series(['2018-05-16', '2018-05-17', '2018-05-18'])
d1 = pd.to_datetime(date_series)
print(d1)
# Out:
# 0   2018-05-16
# 1   2018-05-17
# 2   2018-05-18
# dtype: datetime64[ns]

# %%
print(d1[0].year)
print(d1[0].month)
print(d1[0].day)
# Out:
# 2018
# 5
# 16

# %% [markdown]
# ### **dt 접근자 사용하기**

# %%
ebola = pd.read_csv('/content/country_timeseries.csv')
ebola['date_dt'] = pd.to_datetime(ebola['Date'])

# %% [markdown]
# - dt 접근자 사용하지 않고 인덱스 3 데이터의 년, 월, 일 데이터 추출

# %%
print(ebola[['Date', 'date_dt']].head())

print(ebola['date_dt'][3].year)
print(ebola['date_dt'][3].month)
print(ebola['date_dt'][3].day)
# Out:
#          Date    date_dt
# 0    1/5/2015 2015-01-05
# 1    1/4/2015 2015-01-04
# 2    1/3/2015 2015-01-03
# 3    1/2/2015 2015-01-02
# 4  12/31/2014 2014-12-31
# 2015
# 1
# 2

# %% [markdown]
# - **dt 접근자**로 date_dt 열에 한 번에 접근 -> `year` 속성 이용하여 연도값 추출

# %%
ebola['year'] = ebola['date_dt'].dt.year
print(ebola[['Date', 'date_dt', 'year']].head())
# Out:
#          Date    date_dt  year
# 0    1/5/2015 2015-01-05  2015
# 1    1/4/2015 2015-01-04  2015
# 2    1/3/2015 2015-01-03  2015
# 3    1/2/2015 2015-01-02  2015
# 4  12/31/2014 2014-12-31  2014

# %% [markdown]
# - 월, 일 데이터도 추출

# %%
ebola['month'], ebola['day'] = (ebola['date_dt'].dt.month, ebola['date_dt'].dt.day)

print(ebola[['Date', 'date_dt', 'year', 'month', 'day']].head())
# Out:
#          Date    date_dt  year  month  day
# 0    1/5/2015 2015-01-05  2015      1    5
# 1    1/4/2015 2015-01-04  2015      1    4
# 2    1/3/2015 2015-01-03  2015      1    3
# 3    1/2/2015 2015-01-02  2015      1    2
# 4  12/31/2014 2014-12-31  2014     12   31

# %%
print(ebola.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %% [markdown]
# - **date_dt**: `datetime`
# - **year, month, day**: `int64`(정수형)

# %% [markdown]
# ## **12-2. 사례별 시계열 데이터 계산하기**

# %% [markdown]
# #### **에볼라 최초 발병일 계산**

# %% [markdown]
# - ebola 데이터프레임: 시간 역순으로 정렬 -> 시간순으로 보려면 마지막부터 살펴봐야함

# %%
print(ebola.iloc[-5:,:5])

# 2014년 3월 22일부터 발생하기 시작
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117  3/27/2014    5         103.0            8.0                6.0
# 118  3/26/2014    4          86.0            NaN                NaN
# 119  3/25/2014    3          86.0            NaN                NaN
# 120  3/24/2014    2          86.0            NaN                NaN
# 121  3/22/2014    0          49.0            NaN                NaN

# %% [markdown]
# - min() 메소드 사용해서 찾기

# %%
print(ebola['date_dt'].min())
print(type(ebola['date_dt'].min()))
# Out:
# 2014-03-22 00:00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# - **Timestamp**: `Datetime` 오브젝트와 호환되는 자료형

# %% [markdown]
# - 에볼라의 진행 정도 계산: (Date 열) - (최초 발병일)

# %%
ebola['outbreak_d'] = ebola['date_dt'] - ebola['date_dt'].min()

print(ebola[['Date', 'Day', 'outbreak_d']].head())
# Out:
#          Date  Day outbreak_d
# 0    1/5/2015  289   289 days
# 1    1/4/2015  288   288 days
# 2    1/3/2015  287   287 days
# 3    1/2/2015  286   286 days
# 4  12/31/2014  284   284 days

# %% [markdown]
# #### **파산 은행 개수**

# %%
banks = pd.read_csv('/content/banklist.csv')
print(banks.head())
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date
# 0                   Royal Savings Bank    15-Dec-17    20-Dec-17
# 1                          Conway Bank    13-Oct-17    20-Oct-17
# 2            United Fidelity Bank, fsb    26-May-17    26-Jul-17
# 3  First-Citizens Bank & Trust Company     5-May-17    26-Jul-17
# 4                         Whitney Bank    28-Apr-17     5-Dec-17

# %% [markdown]
# - **Closing Date, Updated Date**: 시계열 데이터

# %%
banks_no_dates = pd.read_csv('/content/banklist.csv')
print(banks_no_dates.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              555 non-null    object
#  1   City                   555 non-null    object
#  2   ST                     555 non-null    object
#  3   CERT                   555 non-null    int64
#  4   Acquiring Institution  555 non-null    object
#  5   Closing Date           555 non-null    object
#  6   Updated Date           555 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 30.5+ KB
# None

# %%
# 문자열로 저장된 시계열 데이터 -> datetime 오브젝트로 변환하여 불러오기
banks = pd.read_csv('/content/banklist.csv', parse_dates=[5,6])
print(banks.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              555 non-null    object
#  1   City                   555 non-null    object
#  2   ST                     555 non-null    object
#  3   CERT                   555 non-null    int64
#  4   Acquiring Institution  555 non-null    object
#  5   Closing Date           555 non-null    datetime64[ns]
#  6   Updated Date           555 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 30.5+ KB
# None

# %% [markdown]
# - `quarter` 속성: 분기 추출

# %%
banks['closing_quarter'], banks['closing_year'] = (banks['Closing Date'].dt.quarter, banks['Closing Date'].dt.year)
print(banks.head())
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date  \
# 0                   Royal Savings Bank   2017-12-15   2017-12-20
# 1                          Conway Bank   2017-10-13   2017-10-20
# 2            United Fidelity Bank, fsb   2017-05-26   2017-07-26
# 3  First-Citizens Bank & Trust Company   2017-05-05   2017-07-26
# 4                         Whitney Bank   2017-04-28   2017-12-05
#
#    closing_quarter  closing_year
# 0                4          2017
# 1                4          2017
# ...

# %%
# 연도별 파산 은행 개수
closing_year = banks.groupby(['closing_year']).size()
print(closing_year)
# Out:
# closing_year
# 2000      2
# 2001      4
# 2002     11
# 2003      3
# 2004      4
# 2007      3
# 2008     25
# 2009    140
# 2010    157
# 2011     92
# 2012     51
# 2013     24
# 2014     18
# 2015      8
# 2016      5
# 2017      8
# dtype: int64

# %% [markdown]
# - `size()`: 호출된 객체의 길이, 크기 계산
#   - 데이터프레임의 속성
#   - series 반환

# %%
# 연도별, 분기별 파산 은행 개수
closing_year_q = banks.groupby(['closing_year', 'closing_quarter']).size()
print(closing_year_q)
# Out:
# closing_year  closing_quarter
# 2000          4                   2
# 2001          1                   1
#               2                   1
#               3                   2
# 2002          1                   6
#               2                   2
#               3                   1
#               4                   2
# 2003          1                   1
#               2                   1
#               4                   1
# 2004          1                   3
#               2                   1
# 2007          1                   1
#               3                   1
#               4                   1
# 2008          1                   2
#               2                   2
#               3                   9
#               4                  12
# 2009          1                  21
#               2                  24
#               3                  50
#               4                  45
# 2010          1                  41
# ...

# %%
# 시각화
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax = closing_year.plot()
plt.show()

fig, ax = plt.subplots()
ax = closing_year_q.plot()
plt.show()

# %% [markdown]
# #### **테슬라 주식 데이터로 시간 계산**

# %%
# !pip install pandas-datareader

# %%
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as pdr

# tesla에 데이터프레임 저장
tesla = pdr.get_data_quandl('TSLA', api_key = 'PbDHh-QHojSha25hxCN7')

# tesla에 저장된 데이터프레임을 파일로 저장
tesla.to_csv('/content/tesla_stock_quandl.csv')

# %%
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as pdr

# tesla에는 데이터프레임이 저장됩니다.
#tesla = pdr.get_data_quandl('TSLA', api_key = '')

# tesla에 저장된 데이터프레임을 파일로 저장합니다.
#tesla.to_csv('/content/tesla_stock_quandl.csv')

tesla = pd.read_csv('/content/tesla_stock_quandl.csv')

# %%
print(tesla.head())
# Out:
#          Date    Open    High     Low   Close      Volume  ExDividend  \
# 0  2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 1  2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2  2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 3  2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 4  2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#    SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 0         1.0   304.00   304.27  277.18    279.18  13696168.0
# 1         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2         1.0   311.25   311.61  300.45    301.54   6600538.0
# 3         1.0   313.89   318.82  308.18    309.10   4914307.0
# 4         1.0   310.25   322.44  310.19    316.53   5927881.0

# %% [markdown]
# - Date 열이 문자열로 저장 -> datetime 오브젝트로 자료형 변환
# - `parse_dates` 인자에 Date 열 전달

# %%
tesla = pd.read_csv('/content/tesla_stock_quandl.csv', parse_dates=[0])
print(tesla.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1949 non-null   datetime64[ns]
#  1   Open        1949 non-null   float64
#  2   High        1949 non-null   float64
#  3   Low         1949 non-null   float64
#  4   Close       1949 non-null   float64
#  5   Volume      1949 non-null   float64
#  6   ExDividend  1949 non-null   float64
#  7   SplitRatio  1949 non-null   float64
#  8   AdjOpen     1949 non-null   float64
#  9   AdjHigh     1949 non-null   float64
#  10  AdjLow      1949 non-null   float64
#  11  AdjClose    1949 non-null   float64
#  12  AdjVolume   1949 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 198.1 KB
# None

# %%
# 불린 추출로 2010년 6월 데이터만 추출
print(tesla.loc[(tesla.Date.dt.year == 2010) & (tesla.Date.dt.month == 6)])
# Out:
#            Date   Open     High    Low  Close      Volume  ExDividend  \
# 1947 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0         0.0
# 1948 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0         0.0
#
#       SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 1947         1.0    25.79  30.4192   23.30     23.83  17187100.0
# 1948         1.0    19.00  25.0000   17.54     23.89  18766300.0

# %% [markdown]
# ### **datetime 오브젝트와 인덱스 - DatetimeIndex**

# %% [markdown]
# **datetime 오브젝트를 인덱스로 설정해 데이터 추출**

# %%
tesla.index = tesla['Date']
print(tesla.index)
# Out:
# DatetimeIndex(['2018-03-27', '2018-03-26', '2018-03-23', '2018-03-22',
#                '2018-03-21', '2018-03-20', '2018-03-19', '2018-03-16',
#                '2018-03-15', '2018-03-14',
#                ...
#                '2010-07-13', '2010-07-12', '2010-07-09', '2010-07-08',
#                '2010-07-07', '2010-07-06', '2010-07-02', '2010-07-01',
#                '2010-06-30', '2010-06-29'],
#               dtype='datetime64[ns]', name='Date', length=1949, freq=None)

# %%
# 2015년 데이터 추출
print(tesla['2015'].iloc[:5,:5])
# Out:
#                  Date    Open     High       Low   Close
# Date
# 2015-12-31 2015-12-31  238.51  243.450  238.3700  240.01
# 2015-12-30 2015-12-30  236.60  243.634  235.6707  238.09
# 2015-12-29 2015-12-29  230.06  237.720  229.5470  237.19
# 2015-12-28 2015-12-28  231.49  231.980  225.5400  228.95
# 2015-12-24 2015-12-24  230.56  231.880  228.2800  230.57
# <ipython-input-73-e6026fbf2efd>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   print(tesla['2015'].iloc[:5,:5])

# %%
# 2010년 6월 데이터 추출
print(tesla['2010-06'].iloc[:,:5])
# Out:
#                  Date   Open     High    Low  Close
# Date
# 2010-06-30 2010-06-30  25.79  30.4192  23.30  23.83
# 2010-06-29 2010-06-29  19.00  25.0000  17.54  23.89
# <ipython-input-75-7ade70181c0c>:2: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   print(tesla['2010-06'].iloc[:,:5])

# %% [markdown]
# ### **시간 간격과 인덱스 - TImedeltaIndex**

# %% [markdown]
# **시간 간격을 인덱스로 지정해 데이터 추출**

# %%
tesla['ref_date'] = tesla['Date'] - tesla['Date'].min()
print(tesla.head())
# Out:
#                  Date    Open    High     Low   Close      Volume  ExDividend  \
# Date
# 2018-03-27 2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 2018-03-26 2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2018-03-23 2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 2018-03-22 2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 2018-03-21 2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#             SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume  \
# Date
# 2018-03-27         1.0   304.00   304.27  277.18    279.18  13696168.0
# 2018-03-26         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2018-03-23         1.0   311.25   311.61  300.45    301.54   6600538.0
# 2018-03-22         1.0   313.89   318.82  308.18    309.10   4914307.0
# 2018-03-21         1.0   310.25   322.44  310.19    316.53   5927881.0
#
#             ref_date
# Date
# 2018-03-27 2828 days
# ...

# %%
tesla.index = tesla['ref_date']
print(tesla.iloc[:5, :5])
# Out:
#                 Date    Open    High     Low   Close
# ref_date
# 2828 days 2018-03-27  304.00  304.27  277.18  279.18
# 2827 days 2018-03-26  307.34  307.59  291.36  304.18
# 2824 days 2018-03-23  311.25  311.61  300.45  301.54
# 2823 days 2018-03-22  313.89  318.82  308.18  309.10
# 2822 days 2018-03-21  310.25  322.44  310.19  316.53

# %%
# 최초 5일 데이터 추출
print(tesla['5 days':].iloc[:5, :5])
# Out:
#                Date   Open     High    Low  Close
# ref_date
# 3 days   2010-07-02  23.00  23.1000  18.71  19.20
# 2 days   2010-07-01  25.00  25.9200  20.27  21.96
# 1 days   2010-06-30  25.79  30.4192  23.30  23.83
# 0 days   2010-06-29  19.00  25.0000  17.54  23.89

# %% [markdown]
# ### **시간 범위와 인덱스**

# %% [markdown]
# **시간 범위 생성해 인덱스로 지정**
# - 누락된 데이터가 있을 때
# - 누락된 데이터도 포함시켜 데이터 살펴보기 -> 임의로 시간 범위를 생성하여 인덱스로 지정

# %%
ebola = pd.read_csv('/content/country_timeseries.csv', parse_dates=[0])
print(ebola.iloc[:5,:5])
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0

# %% [markdown]
# - 2015년 1월 1일 데이터 누락됨

# %%
print(ebola.iloc[-5:,:5])
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN

# %% [markdown]
# - 2014년 3월 22일 데이터 누락됨

# %% [markdown]
# - `date_range()`: 시간 인덱스(DatetimeIndex) 생성

# %%
head_range = pd.date_range(start='2014-12-31', end='2015-01-05')
print(head_range)
# Out:
# DatetimeIndex(['2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
ebola_5 = ebola.head()
ebola_5.index = ebola_5['Date']
ebola_5.reindex(head_range)
print(ebola_5.iloc[:5,:5])
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# Date
# 2015-01-05 2015-01-05  289        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286           NaN         8157.0                NaN
# 2014-12-31 2014-12-31  284        2730.0         8115.0             9633.0

# %% [markdown]
# - `reindex()`에 head_range 전달해서 (누락값 포함된) 새 인덱스 생성

# %%
ebola_5.reindex(head_range)
# Out:
#                  Date    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 2014-12-31 2014-12-31  284.0        2730.0         8115.0             9633.0
# 2015-01-01        NaT    NaN           NaN            NaN                NaN
# 2015-01-02 2015-01-02  286.0           NaN         8157.0                NaN
# 2015-01-03 2015-01-03  287.0        2769.0         8166.0             9722.0
# 2015-01-04 2015-01-04  288.0        2775.0            NaN             9780.0
# 2015-01-05 2015-01-05  289.0        2776.0            NaN            10030.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 2014-12-31            NaN            NaN                 NaN          NaN
# 2015-01-01            NaN            NaN                 NaN          NaN
# 2015-01-02            NaN            NaN                 NaN          NaN
# 2015-01-03            NaN            NaN                 NaN          NaN
# ...

# %% [markdown]
# ### 시간 범위의 주기 설정
# - `DatetimeIndex`의 **`freq`** 속성: DatetimeIndex의 시간 간격 조절
#
#   ![image.png](data:image/png;base64,...)
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **시간 범위 수정하고 데이터 밀어내기 - shift 메서드**

# %% [markdown]
# **에볼라의 확산 속도 비교**

# %%
import matplotlib.pyplot as plt

ebola.index = ebola['Date']

fig, ax = plt.subplots()
ax = ebola.iloc[0:,1:].plot(ax=ax)
ax.legend(fontsize=7, loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# - 각 나라의 에볼라 발병일이 달라 그래프가 그려지기 시작한 지점이 다름
#
#   => 각 나라의 발병일을 가장 처음 에볼라가 발병한 Guinea와 동일한 위치로 옮겨야 나라별 에볼라의 확산 속도 제대로 비교 가능

# %%
ebola_sub = ebola[['Day', 'Cases_Guinea', 'Cases_Liberia']]
print(ebola_sub.tail(10))
# Out:
#             Day  Cases_Guinea  Cases_Liberia
# Date
# 2014-04-04   13         143.0           18.0
# 2014-04-01   10         127.0            8.0
# 2014-03-31    9         122.0            8.0
# 2014-03-29    7         112.0            7.0
# 2014-03-28    6         112.0            3.0
# 2014-03-27    5         103.0            8.0
# 2014-03-26    4          86.0            NaN
# 2014-03-25    3          86.0            NaN
# 2014-03-24    2          86.0            NaN
# 2014-03-22    0          49.0            NaN

# %% [markdown]
# *e.g.* Liberia: 발병일 4만큼 옮겨야 함

# %%
ebola = pd.read_csv('/content/country_timeseries.csv', parse_dates=['Date'])
print(ebola.head().iloc[:,:5])
print(ebola.tail().iloc[:,:5])
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# 117 2014-03-27    5         103.0            8.0                6.0
# 118 2014-03-26    4          86.0            NaN                NaN
# 119 2014-03-25    3          86.0            NaN                NaN
# 120 2014-03-24    2          86.0            NaN                NaN
# 121 2014-03-22    0          49.0            NaN                NaN

# %% [markdown]
# - 중간에 아예 날짜가 없는 데이터도 있음 -> 포함시켜야 확산속도 제대로 비교 가능

# %%
ebola.index = ebola['Date']
new_idx = pd.date_range(ebola.index.min(), ebola.index.max())

# %%
print(new_idx)
# Out:
# DatetimeIndex(['2014-03-22', '2014-03-23', '2014-03-24', '2014-03-25',
#                '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-29',
#                '2014-03-30', '2014-03-31',
#                ...
#                '2014-12-27', '2014-12-28', '2014-12-29', '2014-12-30',
#                '2014-12-31', '2015-01-01', '2015-01-02', '2015-01-03',
#                '2015-01-04', '2015-01-05'],
#               dtype='datetime64[ns]', length=290, freq='D')

# %% [markdown]
# - 시간 순서를 맞추기 위해 인덱스 반대로 뒤집기

# %%
new_idx = reversed(new_idx)

# %% [markdown]
# - **`NaT`**: 시간에 대한 누락값

# %%
ebola = ebola.reindex(new_idx)
print(ebola.head().iloc[:,:5])
print(ebola.tail().iloc[:,:5])
# Out:
#                  Date    Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# Date
# 2015-01-05 2015-01-05  289.0        2776.0            NaN            10030.0
# 2015-01-04 2015-01-04  288.0        2775.0            NaN             9780.0
# 2015-01-03 2015-01-03  287.0        2769.0         8166.0             9722.0
# 2015-01-02 2015-01-02  286.0           NaN         8157.0                NaN
# 2015-01-01        NaT    NaN           NaN            NaN                NaN
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone
# Date
# 2014-03-26 2014-03-26  4.0          86.0            NaN                NaN
# 2014-03-25 2014-03-25  3.0          86.0            NaN                NaN
# 2014-03-24 2014-03-24  2.0          86.0            NaN                NaN
# 2014-03-23        NaT  NaN           NaN            NaN                NaN
# 2014-03-22 2014-03-22  0.0          49.0            NaN                NaN

# %% [markdown]
# - `last_valid_index`: 유효한 값이 있는 마지막 인덱스 = 가장 오래된 데이터
# - `first_valid_index`: 유효한 값이 있는 첫 번째 인덱스 = 가장 최근의 데이터

# %%
# 각 나라의 에볼라 발병일 옮기기
last_valid = ebola.apply(pd.Series.last_valid_index)
print(last_valid)
# Out:
# Date                  2014-03-22
# Day                   2014-03-22
# Cases_Guinea          2014-03-22
# Cases_Liberia         2014-03-27
# Cases_SierraLeone     2014-03-27
# Cases_Nigeria         2014-07-23
# Cases_Senegal         2014-08-31
# Cases_UnitedStates    2014-10-01
# Cases_Spain           2014-10-08
# Cases_Mali            2014-10-22
# Deaths_Guinea         2014-03-22
# Deaths_Liberia        2014-03-27
# Deaths_SierraLeone    2014-03-27
# Deaths_Nigeria        2014-07-23
# Deaths_Senegal        2014-09-07
# Deaths_UnitedStates   2014-10-01
# Deaths_Spain          2014-10-08
# Deaths_Mali           2014-10-22
# dtype: datetime64[ns]

# %%
# 처음 발병한 날(earliest_date)에서 각 나라의 에볼라 발병일을 뺀 만큼(shift_value) 옮기기
earliest_date = ebola.index.min()
print(earliest_date)

shift_values = last_valid - earliest_date
print(shift_values)
# Out:
# 2014-03-22 00:00:00
# Date                    0 days
# Day                     0 days
# Cases_Guinea            0 days
# Cases_Liberia           5 days
# Cases_SierraLeone       5 days
# Cases_Nigeria         123 days
# Cases_Senegal         162 days
# Cases_UnitedStates    193 days
# Cases_Spain           200 days
# Cases_Mali            214 days
# Deaths_Guinea           0 days
# Deaths_Liberia          5 days
# Deaths_SierraLeone      5 days
# Deaths_Nigeria        123 days
# Deaths_Senegal        169 days
# Deaths_UnitedStates   193 days
# Deaths_Spain          200 days
# Deaths_Mali           214 days
# dtype: timedelta64[ns]

# %% [markdown]
# - `shift()`: 인잣값만큼 데이터 밀어내는 메서드

# %%
# 각 나라의 에볼라 발병일 옮기기

ebola_dict = {}
for idx, col in enumerate(ebola):
  d = shift_values[idx].days
  shifted = ebola[col].shift(d)
  ebola_dict[col] = shifted

# %%
ebola_shift = pd.DataFrame(ebola_dict)

# %%
print(ebola_shift.tail())
# Out:
#                  Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# Date
# 2014-03-26 2014-03-26  4.0          86.0            8.0                2.0
# 2014-03-25 2014-03-25  3.0          86.0            NaN                NaN
# 2014-03-24 2014-03-24  2.0          86.0            7.0                NaN
# 2014-03-23        NaT  NaN           NaN            3.0                2.0
# 2014-03-22 2014-03-22  0.0          49.0            8.0                6.0
#
#             Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# Date
# 2014-03-26            1.0            NaN                 1.0          1.0
# 2014-03-25            NaN            NaN                 NaN          NaN
# 2014-03-24            NaN            NaN                 NaN          NaN
# 2014-03-23            NaN            NaN                 NaN          NaN
# 2014-03-22            0.0            1.0                 1.0          1.0
#
# ...

# %%
ebola_shift.index = ebola_shift['Day']
ebola_shift = ebola_shift.drop(['Date','Day'], axis=1)
print(ebola_shift.tail())
# Out:
#      Cases_Guinea  Cases_Liberia  Cases_SierraLeone  Cases_Nigeria  \
# Day
# 4.0          86.0            8.0                2.0            1.0
# 3.0          86.0            NaN                NaN            NaN
# 2.0          86.0            7.0                NaN            NaN
# NaN           NaN            3.0                2.0            NaN
# 0.0          49.0            8.0                6.0            0.0
#
#      Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# Day
# 4.0            NaN                 1.0          1.0         NaN
# 3.0            NaN                 NaN          NaN         NaN
# 2.0            NaN                 NaN          NaN         NaN
# NaN            NaN                 NaN          NaN         NaN
# 0.0            1.0                 1.0          1.0         1.0
#
#      Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# Day
# 4.0           62.0             4.0                 2.0             1.0
# ...

# %%
fig, ax = plt.subplots()
ax = ebola_shift.iloc[:,:].plot(ax=ax)
ax.legend(fontsize=7, loc=2, borderaxespad=0.)
plt.show()
