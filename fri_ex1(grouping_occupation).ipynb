# %% [markdown]
# <a href="https://colab.research.google.com/github/minjeon99/ESAA/blob/Week2/fri_ex1(grouping_occupation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
by_ocp = users.groupby(by='occupation')
by_ocp['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
users['is_male'] = users['gender'].apply(lambda x: True if x == 'M' else False) # 참고
users.groupby(by='occupation').mean('is_male').sort_values(by='is_male', ascending=False)
# Out:
#                   user_id        age   is_male
# occupation
# doctor         533.714286  43.571429  1.000000
# engineer       456.328358  36.388060  0.970149
# technician     497.629630  33.148148  0.962963
# retired        515.714286  63.071429  0.928571
# programmer     435.530303  33.121212  0.909091
# executive      422.312500  38.718750  0.906250
# scientist      465.129032  35.548387  0.903226
# entertainment  398.000000  29.222222  0.888889
# lawyer         359.083333  36.750000  0.833333
# salesman       494.916667  35.666667  0.750000
# educator       466.905263  42.010526  0.726316
# student        484.954082  22.081633  0.693878
# other          542.733333  34.523810  0.657143
# marketing      437.807692  37.615385  0.615385
# writer         495.711111  36.311111  0.577778
# none           368.666667  26.555556  0.555556
# administrator  430.949367  38.746835  0.544304
# artist         451.892857  31.392857  0.535714
# librarian      486.588235  40.000000  0.431373
# ...

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
by_ocp['age'].agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(by=['occupation','gender']).mean()
# Out:
# <ipython-input-44-3e79faef290c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   users.groupby(by=['occupation','gender']).mean()
#                          user_id        age  is_male
# occupation    gender
# administrator F       443.944444  40.638889      0.0
#               M       420.069767  37.162791      1.0
# artist        F       432.153846  30.307692      0.0
#               M       469.000000  32.333333      1.0
# doctor        M       533.714286  43.571429      1.0
# educator      F       454.730769  39.115385      0.0
#               M       471.492754  43.101449      1.0
# engineer      F       806.500000  29.500000      0.0
#               M       445.553846  36.600000      1.0
# entertainment F       780.000000  31.000000      0.0
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
# 5번과 유사
users['is_male'] = users['gender'].apply(lambda x: True if x == 'M' else False)
users['is_female'] = users['gender'].apply(lambda x: True if x == 'F' else False)
users.groupby(by='occupation')[['is_male','is_female']].mean()
# Out:
#                 is_male  is_female
# occupation
# administrator  0.544304   0.455696
# artist         0.535714   0.464286
# doctor         1.000000   0.000000
# educator       0.726316   0.273684
# engineer       0.970149   0.029851
# entertainment  0.888889   0.111111
# executive      0.906250   0.093750
# healthcare     0.312500   0.687500
# homemaker      0.142857   0.857143
# lawyer         0.833333   0.166667
# librarian      0.431373   0.568627
# marketing      0.615385   0.384615
# none           0.555556   0.444444
# other          0.657143   0.342857
# programmer     0.909091   0.090909
# retired        0.928571   0.071429
# salesman       0.750000   0.250000
# scientist      0.903226   0.096774
# student        0.693878   0.306122
# technician     0.962963   0.037037
# writer         0.577778   0.422222
