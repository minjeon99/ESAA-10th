# %% [markdown]
# <a href="https://colab.research.google.com/github/minjeon99/ESAA_YB/blob/Week10/w10_fri_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 단순 선형 회귀 분석**
# - 전복의 나이를 예측하는 선형회귀모델을 생성하세요.
# - 전복의 ‘성별’, ‘키’, ‘지름’, ‘높이’, ‘전체무게’, ‘몸통무게’, ‘내장무게’, ‘껍질무게’를 이용해 ‘껍질의 고리 수’를 예측한 뒤, **예측된 ‘껍질의 고리 수’에 1.5를 더하면 전복의 나이**가 됩니다.

# %%
# 기본 모듈 불러오기
import numpy as np
import pandas as pd

# %% [markdown]
# **1) 데이터 load 및 변형**

# %%
# 데이터 로드
data = pd.read_csv("./abalone.csv")
data.head()
print(data.shape)

# 성별 M은 Male, F는 Female, I는 Infant 이므로 따로 열 만들기
for label in "MFI":
    data[label] = data["Sex"] == label
data.drop('Sex', axis=1, inplace=True)
# Out:
# (4177, 9)

# %%
data.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings      M      F      I
# 0         0.150     15   True  False  False
# 1         0.070      7   True  False  False
# 2         0.210      9  False   True  False
# 3         0.155     10   True  False  False
# 4         0.055      7  False  False   True

# %% [markdown]
# **2) X, y 선택**
# : y는 Rings열, X는 Rings열을 제외한 나머지를 선택하되 전부 실수가 되도록 한다.

# %%
# X,y 데이터 선택
y = data['Rings']

X = data.drop(columns=['Rings']).astype(float)
X
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight    M    F    I
# ...

# %% [markdown]
#  **3) train/test set 분리**

# %%
# 필요한 모듈 불러오기
from sklearn.model_selection import train_test_split

# %%
# train과 test set 분리 (train:test = 7:3 비율로)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# **4) 선형회귀모델 생성, 모델 예측치 구하기**

# %%
#필요한 모듈 불러오기
from sklearn.linear_model import LinearRegression

# %%
#선형회귀모델 생성 및 훈련
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 모델 예측치 구하기
pred = lr.predict(X_test)
# 모델 예측치를 활용해 최종적으로 전복의 나이를 예측
pred_age = pred + 1.5

# %% [markdown]
# **5) 모델 평가: MSE, RMSE, R2 score, corr 구하기**

# %%
#필요한 모듈 불러오기
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# - MSE, RMSE

# %%
#mse, rmse
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)

print(mse, rmse)
# Out:
# 5.471062373880256 2.3390302208138003

# %% [markdown]
# - R2 score

# %%
#R2 score 측정
r2 = r2_score(y_test, pred)
print(r2)
# Out:
# 0.4810167575737109

# %% [markdown]
# - 회귀 절편값

# %%
#회귀 절편 값
lr.intercept_
# Out:
# 3.3304579450161738

# %% [markdown]
# - 회귀 계수 값

# %%
#회귀 계수 값
lr.coef_
# Out:
# array([ -1.5759866 ,  10.46896153,  21.3085454 ,   8.27662143,
#        -18.97345786, -11.7158735 ,   9.4096176 ,   0.34670113,
#          0.21683092,  -0.56353206])

# %% [markdown]
# - 상관계수
#
# Hint: corr 함수 이용.

# %%
# 상관계수 구하기
df = pd.DataFrame({'pred':pred, 'true':y_test})
cor = df['pred'].corr(df['true'])
cor
# Out:
# 0.6955715636482361

# %% [markdown]
# # **2. Polynomial features**

# %%
# PolynomialFeatures 라이브러리 호출
from sklearn.preprocessing import PolynomialFeatures

# %%
# 임의 데이터 생성

X = np.arange(6).reshape(3, 2)

df =  pd.DataFrame(X)
df.columns = ['x_1','x_2']
df
# Out:
#    x_1  x_2
# 0    0    1
# 1    2    3
# 2    4    5

# %%
# 차원은 2로 설정
# fit_transform 메소드를 통해 데이터 변환
# PolynomialFeatures로 변환 된 데이터를 데이터 프레임 형태로 변환
ftr = PolynomialFeatures(degree=2)
df_poly = ftr.fit_transform(df)
df_poly = pd.DataFrame(df_poly)
df_poly
# Out:
#      0    1    2     3     4     5
# 0  1.0  0.0  1.0   0.0   0.0   1.0
# 1  1.0  2.0  3.0   4.0   6.0   9.0
# 2  1.0  4.0  5.0  16.0  20.0  25.0

# %%
# df_poly의 컬럼을 1,x1,x2,x1^2,x1*x2,x2^2 로 변경
df_poly.columns = ['1','x1','x2','x1^2','x1*x2','x2^2']
df_poly
# Out:
#      1   x1   x2  x1^2  x1*x2  x2^2
# 0  1.0  0.0  1.0   0.0    0.0   1.0
# 1  1.0  2.0  3.0   4.0    6.0   9.0
# 2  1.0  4.0  5.0  16.0   20.0  25.0
